# %%
import pandas as pd

# %%
data = pd.read_csv("D:/Desktop/Desktop_Important/ATI/CityTaxi/test.csv")

# %%
data.head()
# Out:
#                            key          pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002  2015-01-27 13:08:24 UTC        -73.973320
# 1  2015-01-27 13:08:24.0000003  2015-01-27 13:08:24 UTC        -73.986862
# 2  2011-10-08 11:53:44.0000002  2011-10-08 11:53:44 UTC        -73.982524
# 3  2012-12-01 21:12:12.0000002  2012-12-01 21:12:12 UTC        -73.981160
# 4  2012-12-01 21:12:12.0000003  2012-12-01 21:12:12 UTC        -73.966046
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.763805         -73.981430         40.743835                1
# 1        40.719383         -73.998886         40.739201                1
# 2        40.751260         -73.979654         40.746139                1
# 3        40.767807         -73.990448         40.751635                1
# 4        40.789775         -73.988565         40.744427                1

# %%
data["pickup_datetime"]=pd.to_datetime(data["pickup_datetime"])

# %%
data.head()
# Out:
#                            key     pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002 2015-01-27 13:08:24        -73.973320
# 1  2015-01-27 13:08:24.0000003 2015-01-27 13:08:24        -73.986862
# 2  2011-10-08 11:53:44.0000002 2011-10-08 11:53:44        -73.982524
# 3  2012-12-01 21:12:12.0000002 2012-12-01 21:12:12        -73.981160
# 4  2012-12-01 21:12:12.0000003 2012-12-01 21:12:12        -73.966046
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.763805         -73.981430         40.743835                1
# 1        40.719383         -73.998886         40.739201                1
# 2        40.751260         -73.979654         40.746139                1
# 3        40.767807         -73.990448         40.751635                1
# 4        40.789775         -73.988565         40.744427                1

# %%
data["pickup_datetime"].dt.year.head()
# Out:
# 0    2015
# 1    2015
# 2    2011
# 3    2012
# 4    2012
# Name: pickup_datetime, dtype: int64

# %%
data["pickup_datetime"].dt.month.head()
# Out:
# 0     1
# 1     1
# 2    10
# 3    12
# 4    12
# Name: pickup_datetime, dtype: int64

# %%
data["pickup_datetime"].dt.day.head()
# Out:
# 0    27
# 1    27
# 2     8
# 3     1
# 4     1
# Name: pickup_datetime, dtype: int64

# %%
data["pickup_datetime"].dt.hour.head()
# Out:
# 0    13
# 1    13
# 2    11
# 3    21
# 4    21
# Name: pickup_datetime, dtype: int64

# %%
data["pickup_datetime"].dt.dayofweek.head()
# Out:
# 0    1
# 1    1
# 2    5
# 3    5
# 4    5
# Name: pickup_datetime, dtype: int64

# %%
data["pickup_datetime"].dt.dayofyear.head()
# Out:
# 0     27
# 1     27
# 2    281
# 3    336
# 4    336
# Name: pickup_datetime, dtype: int64

# %%
data["pickup_datetime"].dt.time.head()
# Out:
# 0    13:08:24
# 1    13:08:24
# 2    11:53:44
# 3    21:12:12
# 4    21:12:12
# Name: pickup_datetime, dtype: object

# %%
data["pickup_datetime"].dt.weekday_name.head()
# Out:
# 0     Tuesday
# 1     Tuesday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: pickup_datetime, dtype: object

# %%
help(pd.to_datetime)
# Out:
# Help on function to_datetime in module pandas.core.tools.datetimes:
#
# to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format=None, exact=True, unit=None, infer_datetime_format=False, origin='unix', cache=False)
#     Convert argument to datetime.
#
#     Parameters
#     ----------
#     arg : integer, float, string, datetime, list, tuple, 1-d array, Series
#
#         .. versionadded:: 0.18.1
#
#            or DataFrame/dict-like
#
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#
#         - If 'raise', then invalid parsing will raise an exception
#         - If 'coerce', then invalid parsing will be set as NaT
#         - If 'ignore', then invalid parsing will return the input
#     dayfirst : boolean, default False
#         Specify a date parse order if `arg` is str or its list-likes.
#         If True, parses dates with the day first, eg 10/11/12 is parsed as
#         2012-11-10.
# ...

# %%
print(pd.to_datetime('01/01/2019'))
# Out:
# 2019-01-01 00:00:00

# %%
print(pd.to_datetime('13000101', format='%Y%m%d', errors='ignore'))
# Out:
# 1300-01-01 00:00:00

# %%
pd.to_datetime('1/1/2019')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.to_datetime('10/9/2019')
# Out:
# Timestamp('2019-10-09 00:00:00')

# %%
data.head()
# Out:
#                            key     pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002 2015-01-27 13:08:24        -73.973320
# 1  2015-01-27 13:08:24.0000003 2015-01-27 13:08:24        -73.986862
# 2  2011-10-08 11:53:44.0000002 2011-10-08 11:53:44        -73.982524
# 3  2012-12-01 21:12:12.0000002 2012-12-01 21:12:12        -73.981160
# 4  2012-12-01 21:12:12.0000003 2012-12-01 21:12:12        -73.966046
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.763805         -73.981430         40.743835                1
# 1        40.719383         -73.998886         40.739201                1
# 2        40.751260         -73.979654         40.746139                1
# 3        40.767807         -73.990448         40.751635                1
# 4        40.789775         -73.988565         40.744427                1

# %%
date_t=pd.to_datetime('1/10/2015')

# %%
data["pickup_datetime"].max()
# Out:
# Timestamp('2015-06-30 20:03:50')

# %%
data["pickup_datetime"].min()
# Out:
# Timestamp('2009-01-01 11:04:24')

# %% [markdown]
# # Code	Meaning	Example
# ##### %A	Weekday as locale’s full name.	Wednesday
# #### %a	Weekday as locale’s abbreviated name.	Wed
# #### %B	Month as locale’s full name.	June
# #### %d	Day of the month.	06
# #### %m	Month as a number.	6
# #### %Y	Four-digit year.	2018
# #### %y	Two-digit year.	18

# %%
# Define dates as strings
date_str1 = 'Wednesday, June 6, 2018'
date_str2 = '6/6/18'
date_str3 = '06-06-2018'

# %%
# Define dates as strings
date_str1 = 'Wednesday, June 6, 2018'
date_str2 = '6/6/18'
date_str3 = '06-06-2018'

# Define dates as datetime objects
date_dt1 = pd.to_datetime(date_str1, format = '%A, %B %d, %Y')
date_dt2 = pd.to_datetime(date_str2, format = '%m/%d/%y')
date_dt3 = pd.to_datetime(date_str3, format = '%m-%d-%Y')

# Print converted dates
print(date_dt1)
print(date_dt2)
print(date_dt3)
# Out:
# 2018-06-06 00:00:00
# 2018-06-06 00:00:00
# 2018-06-06 00:00:00

# %%
date_t
# Out:
# Timestamp('2015-01-10 00:00:00')

# %%
data[data["pickup_datetime"]>date_t]
# Out:
#                               key     pickup_datetime  pickup_longitude  \
# 0     2015-01-27 13:08:24.0000002 2015-01-27 13:08:24        -73.973320
# 1     2015-01-27 13:08:24.0000003 2015-01-27 13:08:24        -73.986862
# 180   2015-02-21 15:52:44.0000004 2015-02-21 15:52:44        -73.999641
# 181   2015-02-21 15:52:44.0000003 2015-02-21 15:52:44        -73.997681
# 182   2015-02-21 15:52:44.0000002 2015-02-21 15:52:44        -73.984390
# 183   2015-02-21 15:52:44.0000001 2015-02-21 15:52:44        -73.980438
# 198   2015-01-31 20:54:04.0000001 2015-01-31 20:54:04        -74.001373
# 285   2015-06-08 20:02:56.0000001 2015-06-08 20:02:56        -73.975426
# 566   2015-05-30 21:29:04.0000004 2015-05-30 21:29:04        -73.959389
# 567   2015-05-30 21:29:04.0000007 2015-05-30 21:29:04        -74.017174
# 568   2015-05-30 21:29:04.0000003 2015-05-30 21:29:04        -73.991524
# 569   2015-05-30 21:29:04.0000001 2015-05-30 21:29:04        -73.982887
# ...

# %%
data.sort_values(["passenger_count"],ascending=False)
# Out:
#                                 key     pickup_datetime  pickup_longitude  \
# 9913    2015-01-18 14:06:23.0000006 2015-01-18 14:06:23        -73.988022
# 9781   2011-03-11 01:44:00.00000062 2011-03-11 01:44:00        -73.966473
# 9801  2014-04-27 02:57:00.000000144 2014-04-27 02:57:00        -73.983298
# 9800  2014-04-27 02:57:00.000000179 2014-04-27 02:57:00        -73.982872
# 9799  2014-04-27 02:57:00.000000183 2014-04-27 02:57:00        -74.008648
# 9798   2014-04-27 02:57:00.00000066 2014-04-27 02:57:00        -74.002670
# 9797  2014-04-27 02:57:00.000000173 2014-04-27 02:57:00        -73.994037
# 9796   2014-04-27 02:57:00.00000091 2014-04-27 02:57:00        -73.972880
# 9795  2014-04-27 02:57:00.000000166 2014-04-27 02:57:00        -74.003945
# 9794    2014-04-27 02:57:00.0000004 2014-04-27 02:57:00        -73.989067
# 9793  2014-04-27 02:57:00.000000178 2014-04-27 02:57:00        -74.002558
# 9792   2014-04-27 02:57:00.00000075 2014-04-27 02:57:00        -74.005278
# ...
